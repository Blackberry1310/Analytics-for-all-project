# %% [markdown]
# <a href="https://colab.research.google.com/github/Blackberry1310/Analytics-for-all-project/blob/main/Project_File_of_python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#reading data of 2015

df_2015 = pd.read_csv("2015.csv")
print(df_2015)
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#reading data of 2016
df_2016 = pd.read_csv("2016.csv")
print(df_2016)
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
#reading data of 2017
df_2017 = pd.read_csv("2017.csv")
print(df_2017)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
#reading data of 2018
df_2018 = pd.read_csv("2018.csv")
print(df_2018)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
#reading data of 2019
df_2019 = pd.read_csv("2019.csv")
print(df_2019)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# Cleaning column names using pandas library
df.columns = df.columns.str.strip().str.replace(' ', '_')
print(df.columns)
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
plt.grid()
c =['brown','red','blue','green','violet','gold','lightblue','indigo','pink','yellow']
plt.barh(Country_or_region,score, color = c,align='center')
plt.title('Top 10 Happiest Countries by Score')
plt.xlabel("Country or Region")
plt.ylabel("Happiness Score")
plt.show()

# %%
plt.grid()
bottom10 = df.nsmallest(10, 'Score')
c =['brown','red','blue','green','violet','gold','lightblue','indigo','pink','yellow']
plt.barh(bottom10['Country_or_region'], bottom10['Score'], color=c)
plt.title('Bottom 10 Countries')
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.show()

# %%
#Average Score Per year
plt.grid()
df_combined = pd.concat([
    df_2015.assign(Year=2015, Country=df_2015['Country'], Score=df_2015['Happiness Score'], GDP_per_capita=df_2015['Economy (GDP per Capita)'], Social_support=df_2015['Family']),
    df_2016.assign(Year=2016, Country=df_2016['Country'], Score=df_2016['Happiness Score'], GDP_per_capita=df_2016['Economy (GDP per Capita)'], Social_support=df_2016['Family']),
    df_2017.assign(Year=2017, Country=df_2017['Country'], Score=df_2017['Happiness.Score'], GDP_per_capita=df_2017['Economy..GDP.per.Capita.'], Social_support=df_2017['Family']),
    df_2018.assign(Year=2018, Country=df_2018['Country or region'], Score=df_2018['Score'], GDP_per_capita=df_2018['GDP per capita'], Social_support=df_2018['Social support']),
    df_2019.assign(Year=2019, Country=df_2019['Country or region'], Score=df_2019['Score'], GDP_per_capita=df_2019['GDP per capita'], Social_support=df_2019['Social support'])
])
c =['brown','red','blue','green','violet']
avg_score = df_combined.groupby('Year')['Score'].mean()
plt.bar(avg_score.index, avg_score.values, color = c)
plt.title('Average Happiness Score per Year')
plt.xlabel('Year')
plt.ylabel('Score')
plt.show()

# %%
print(df_combined.columns)
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year', 'Score', 'GDP_per_capita',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Happiness.Rank', 'Happiness.Score', 'Whisker.high', 'Whisker.low',
#        'Economy..GDP.per.Capita.', 'Health..Life.Expectancy.',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Overall rank',
#        'Country or region', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#  Top GDP countries
plt.grid()
c =['brown','red','blue','green','violet','gold','lightblue','indigo','pink','yellow']
top_gdp = df.nlargest(10, 'GDP_per_capita')
plt.barh(top_gdp['Country_or_region'], top_gdp['GDP_per_capita'], color = c)
plt.title('Top GDP Countries')
plt.xlabel('GDP per Capita')
plt.ylabel('Country')
plt.show()

# %%
# Social Support
plt.grid()
c =['brown','red','blue','green','violet','gold','lightblue','indigo','pink','yellow']
top_social = df.nlargest(10, 'Social_support')
plt.barh(top_social['Country_or_region'], top_social['Social_support'], color = c)
plt.title('Top Social Support')
plt.xlabel('Social Support')
plt.ylabel('Country')
plt.show()

# %%
#Freedom
plt.grid()
c =['black']
plt.hist(df['Freedom_to_make_life_choices'], bins=20, edgecolor = c, alpha = 0.2)
plt.title('Distribution of Freedom to Make Life Choices')
plt.xlabel('Freedom')
plt.ylabel('Frequency')
plt.show()

# %%
#Generosity
plt.grid()
c =['black']
plt.hist(df['Generosity'], bins=20, edgecolor = c, alpha = 0.5, color = 'purple')
plt.title('Distribution of Generosity')
plt.xlabel('Generosity')
plt.ylabel('Frequency')
plt.show()

# %%
#Corruption
plt.grid()
c =['black']
plt.hist(df['Perceptions_of_corruption'], bins=20, edgecolor = c, alpha = 0.8, color = 'red')
plt.title('Distribution of Perceptions of Corruption')
plt.xlabel('Perceptions of Corruption')
plt.ylabel('Frequency')
plt.show()

# %%
#Score Distribution
plt.grid()
c =['black']
plt.hist(df['Score'], bins=20, edgecolor = c, alpha = 0.5)
plt.title('Distribution of Happiness Score')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
#GDP Distribution
plt.grid()
c =['black']
plt.hist(df['GDP_per_capita'], bins=20, edgecolor = c, alpha = 0.3, color = 'pink')
plt.title('Distribution of GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Frequency')
plt.show()

# %%
#Golbal Happiness trend
plt.grid()
avg_score = df_combined.groupby('Year')['Score'].mean()
plt.plot(avg_score.index, avg_score.values, marker='v', color = "Black")
plt.title('Global Happiness Trend')
plt.xlabel('Year')
plt.ylabel('Score')
plt.show()

# %%
#GDP trend
plt.grid()
gdp = df_combined.groupby('Year')['GDP_per_capita'].mean()
plt.plot(gdp.index, gdp.values, marker='d', color = "Green")
plt.title('GDP Trend')
plt.show()

# %%
#Social Support Trend
plt.grid()
social = df_combined.groupby('Year')['Social_support'].mean()
plt.plot(social.index, social.values, marker='o', color = "Yellow")
plt.title('Social Support Trend')
plt.show()

# %%
# Single Country
# To plot a country's happiness trend across years, use df_combined and filter for the specific country.
# For example, to plot the trend for Finland (which is the first country in df):
plt.grid()
country_to_plot = df['Country_or_region'].iloc[0] # Get the first country from the current df
country_data_combined = df_combined[df_combined['Country'] == country_to_plot]

plt.plot(country_data_combined['Year'], country_data_combined['Score'], marker='s', color = "red")
plt.title(f'{country_to_plot} Happiness Trend')
plt.xlabel('Year')
plt.ylabel('Score')
plt.show()

# %%
#Multiple couontries
plt.grid()
countries = df['Country_or_region'].unique()[:5]

for c in countries:
    data = df_combined[df_combined['Country'] == c] # Use df_combined and the 'Country' column
    plt.plot(data['Year'], data['Score'], marker='o', label=c)

plt.legend()
plt.title('Country Comparison')
plt.xlabel('Year')
plt.ylabel('Score')
plt.show()

# %%
#Top 5 Share
top5 = df.nlargest(5, 'Score')
plt.pie(top5['Score'], labels=top5['Country_or_region'], autopct='%1.1f%%')
plt.title('Top 5 Happiness Share')
plt.show()

# %%
# Score Category
bins = pd.cut(df['Score'], bins=3, labels=['Low','Medium','High'])
counts = bins.value_counts()
plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%', explode = (0,0.2,0))
plt.title('Score Distribution')
plt.show()

# %%
row = df.iloc[0]
factors = ['GDP_per_capita','Social_support','Freedom_to_make_life_choices','Generosity','Perceptions_of_corruption']

values = [row[f] for f in factors]
plt.pie(values, labels=factors, autopct='%1.1f%%' , explode = (0.1,0,0.1,0,0))
plt.title('Factor Contribution')
plt.show()

# %%
# GDP vs Score
plt.grid()
plt.scatter(df['GDP_per_capita'], df['Score'])
plt.xlabel('GDP')
plt.ylabel('Score')
plt.title('GDP vs Score')
plt.show()

# %%
#Social vs Score
plt.grid()
plt.scatter(df['Social_support'], df['Score'], color = 'purple')
plt.xlabel('Social Support')
plt.ylabel('Score')
plt.title('Social Support vs Score')
plt.show()

# %%
#Freedom vs Score
plt.grid()
plt.scatter(df['Freedom_to_make_life_choices'], df['Score'],color = 'green')
plt.xlabel('Freedom')
plt.ylabel('Score')
plt.title('Freedom vs Score')
plt.show()

# %%
#Generosity vs Score
plt.grid()
plt.scatter(df['Generosity'], df['Score'], color = 'red')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.title('Generosity vs Score')
plt.show()
